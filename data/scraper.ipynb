# %%
import scraper as ds
import pandas as pd
import explorer as de

# %%
## Getting the data which doesn't have null values
data = ds.dataScraperRecipeLink(123)
df = pd.DataFrame(data)
df = df.dropna()
df.reset_index(inplace=True, drop=True)
df.to_csv("data.csv", index=False)

# %%
df = pd.read_csv("data.csv")

# %%
de.find_min_max_values(df)
# Out:
# {'prep_time_mins': {'min': 0, 'max': 1080},
#  'cook_time_mins': {'min': 0, 'max': 480},
#  'total_time_mins': {'min': 0, 'max': 1125},
#  'servings': {'min': 1.0, 'max': 50.0},
#  'protien_per_serving_grams': {'min': 0.0, 'max': 157.28},
#  'carbs_per_serving_grams': {'min': 0.25, 'max': 315.1},
#  'calories_per_serving_kcal': {'min': 5.0, 'max': 2679.5},
#  'fat_per_serving_grams': {'min': 0.0, 'max': 257.38},
#  'sodium_per_serving_mg': {'min': 1.0, 'max': 3554.0},
#  'fiber_per_serving_mg': {'min': 0.0, 'max': 39.66}}

# %%
result
# Out:
#                                                     url  prep_time_mins  \
# 5      https://www.budgetbytes.com/gingerbread-cookies/              30
# 6     https://www.budgetbytes.com/homemade-cinnamon-...              30
# 22          https://www.budgetbytes.com/caramel-apples/              30
# 30     https://www.budgetbytes.com/chocolate-cream-pie/              30
# 93           https://www.budgetbytes.com/cabbage-rolls/              45
# ...                                                 ...             ...
# 1334  https://www.budgetbytes.com/teriyaki-pork-sand...              30
# 1339  https://www.budgetbytes.com/lobster-cream-chee...              40
# 1341  https://www.budgetbytes.com/dolmas-stuffed-gra...              45
# 1348  https://www.budgetbytes.com/pork-ginger-pot-st...              45
# 1349  https://www.budgetbytes.com/stuffed-poblano-pe...              30
#
#       cook_time_mins  total_time_mins  servings  protien_per_serving_grams  \
# ...
